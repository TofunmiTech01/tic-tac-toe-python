# %% [markdown]
# ## TIC-TAC-TOE PYTHON PROJECT BY OLUWATOFUNMI ISHOLADANIEL

# %%
## Tic Tac Toe Game (2-Player Console Version) with Scoreboard

def print_board(board):
    print()
    print(f" {board[0]} | {board[1]} | {board[2]}")
    print("---+---+---")
    print(f" {board[3]} | {board[4]} | {board[5]}")
    print("---+---+---")
    print(f" {board[6]} | {board[7]} | {board[8]}")
    print()


def check_winner(board):
    win_positions = [
        (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
        (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
        (0, 4, 8), (2, 4, 6)              # Diagonals
    ]

    for a, b, c in win_positions:
        if board[a] == board[b] == board[c] and board[a] in ["X", "O"]:
            return board[a]
    return None


def is_draw(board):
    for cell in board:
        if cell not in ["X", "O"]:
            return False
    return True


def get_move(player, board):
    while True:
        try:
            move = int(input(f"Player {player}, enter your move (1-9): "))
            if move < 1 or move > 9:
                print("Please enter a number between 1 and 9.")
                continue

            index = move - 1
            if board[index] in ["X", "O"]:
                print("That position is already taken.")
                continue

            return index
        except ValueError:
            print("Invalid input. Please enter a number.")


# Scoreboard variables
x_wins = 0
o_wins = 0


def play_game():
    board = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
    current_player = "X"

    print("Welcome to Tic Tac Toe!")
    print_board(board)

    while True:
        move = get_move(current_player, board)
        board[move] = current_player
        print_board(board)

        winner = check_winner(board)
        if winner:
            print(f"Player {winner} wins! 🎉")
            return winner

        if is_draw(board):
            print("It's a draw! 🤝")
            return "draw"

        # Switch player
        if current_player == "X":
            current_player = "O"
        else:
            current_player = "X"


# Main Loop with scoreboard
while True:
    result = play_game()

    if result == "X":
        x_wins += 1
    elif result == "O":
        o_wins += 1

    print(f"\nScoreboard -> X: {x_wins} wins | O: {o_wins} wins\n")

    again = input("Play again? (y/n): ").lower()
    if again != "y":
        print("Thanks for playing!")
        break
# Out:
# Welcome to Tic Tac Toe!
#
#  1 | 2 | 3
# ---+---+---
#  4 | 5 | 6
# ---+---+---
#  7 | 8 | 9
# Player X, enter your move (1-9):  2
#  1 | X | 3
# ---+---+---
#  4 | 5 | 6
# ---+---+---
#  7 | 8 | 9
# Player O, enter your move (1-9):  5
#  1 | X | 3
# ---+---+---
#  4 | O | 6
# ---+---+---
#  7 | 8 | 9
# Player X, enter your move (1-9):  3
#  1 | X | X
# ---+---+---
#  4 | O | 6
# ---+---+---
#  7 | 8 | 9
# Player O, enter your move (1-9):  1
#  O | X | X
# ---+---+---
#  4 | O | 6
# ---+---+---
#  7 | 8 | 9
# Player X, enter your move (1-9):  9
#  O | X | X
# ---+---+---
#  4 | O | 6
# ---+---+---
#  7 | 8 | X
# Player O, enter your move (1-9):  6
#  O | X | X
# ---+---+---
#  4 | O | O
# ---+---+---
#  7 | 8 | X
# Player X, enter your move (1-9):  4
#  O | X | X
# ---+---+---
#  X | O | O
# ---+---+---
#  7 | 8 | X
# Player O, enter your move (1-9):  7
#  O | X | X
# ---+---+---
#  X | O | O
# ---+---+---
#  O | 8 | X
# Player X, enter your move (1-9):  8
#  O | X | X
# ---+---+---
# ...
